# %%
import numpy as np
np.set_printoptions(threshold=np.inf)

# %%
# Set the length of the vectors
vector_length = 100

# Generate 50 random bipolar vectors
vectors = np.random.choice([-1, 1], size=(50, vector_length))
weights = np.zeros((100,100))

# %%
weights = np.zeros((100,100))

for h in range(len(vectors)):
    # iterate through the rows
    for i in range(len(weights)):
        # iterate through the columns, starting from the diagonal
        for j in range(i+1, len(weights)):
            # access and print only the upper triangle elements
            weights[i,j] += (vectors[h][i] * vectors[h][j])
            weights[j,i] = weights[i,j]

    print(f"Iteration {h}\n")
    for k in range(len(weights)):
        state = vectors[h]
        output_state = np.zeros((100))
        wxs = weights[k] * state
        sum = np.sum(wxs)
        if sum >= 0:
            output_state[k] = 1
        else:
            output_state[k] = -1
        if output_state[k] != state[k]:
            print(i, "bruh")
# Out:
# Iteration 0
#
# Iteration 1
#
# Iteration 2
#
# Iteration 3
#
# Iteration 4
#
# Iteration 5
#
# Iteration 6
#
# Iteration 7
#
# Iteration 8
#
# Iteration 9
#
# Iteration 10
#
# Iteration 11
#
# Iteration 12
#
# Iteration 13
#
# Iteration 14
#
# Iteration 15
#
# Iteration 16
#
# Iteration 17
#
# 99 bruh
# Iteration 18
#
# Iteration 19
#
# Iteration 20
#
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 21
#
# 99 bruh
# 99 bruh
# Iteration 22
#
# Iteration 23
#
# 99 bruh
# Iteration 24
#
# Iteration 25
#
# Iteration 26
#
# 99 bruh
# 99 bruh
# Iteration 27
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 28
#
# Iteration 29
#
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 30
#
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 31
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 32
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 33
#
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 34
#
# 99 bruh
# 99 bruh
# Iteration 35
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 36
#
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 37
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 38
#
# 99 bruh
# Iteration 39
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 40
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 41
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 42
#
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 43
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 44
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 45
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 46
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 47
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 48
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# Iteration 49
#
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh
# 99 bruh

# %%
# Out:
# 9 bruh
# 37 bruh
# 49 bruh
# 57 bruh
# 67 bruh
# 69 bruh
# 75 bruh
# 93 bruh
# 98 bruh
